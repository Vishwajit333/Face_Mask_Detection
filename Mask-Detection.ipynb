# %%
import os

# %%
from keras.preprocessing import image

# %%
import cv2

# %%
categories = ['with_mask','without_mask']

# %%
data = []
for category in categories:
    path = os.path.join('data',category)
    
    label = categories.index(category)

    for file in os.listdir(path) :

        img_path = os.path.join(path,file)
        img = cv2.imread(img_path)
        img = cv2.resize(img,(224,224))

        data.append([img,label])

# %%
len(data)
# Out:
# 2074

# %%
import random

# %%
random.shuffle(data)

# %%
X = []
y = []
for features,label in data :
    X.append(features)
    y.append(label)

# %%
len(X)
# Out:
# 2074

# %%
len(y)
# Out:
# 2074

# %%
import numpy as np

# %%
X = np.array(X)

y = np.array(y)

# %%
X.shape
# Out:
# (2074, 224, 224, 3)

# %%
y.shape
# Out:
# (2074,)

# %%
X = X/255

# %%
X[0]
# Out:
# array([[[0.37647059, 0.31764706, 0.30980392],
#         [0.36470588, 0.30588235, 0.29803922],
#         [0.35294118, 0.29411765, 0.29019608],
#         ...,
#         [0.98431373, 0.98431373, 0.98431373],
#         [0.98431373, 0.98431373, 0.98431373],
#         [0.98431373, 0.98431373, 0.98431373]],
#
#        [[0.37647059, 0.31764706, 0.30980392],
#         [0.37647059, 0.31764706, 0.30980392],
#         [0.37647059, 0.31764706, 0.30980392],
#         ...,
#         [0.98431373, 0.98431373, 0.98431373],
#         [0.98431373, 0.98431373, 0.98431373],
#         [0.98431373, 0.98431373, 0.98431373]],
#
#        [[0.36862745, 0.30980392, 0.30196078],
#         [0.38039216, 0.32156863, 0.31372549],
#         [0.39215686, 0.33333333, 0.3254902 ],
#         ...,
#         [0.98431373, 0.98431373, 0.98431373],
#         [0.98431373, 0.98431373, 0.98431373],
#         [0.98431373, 0.98431373, 0.98431373]],
#
#        ...,
#
#        [[0.5254902 , 0.57254902, 0.64313725],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (1659, 224, 224, 3)

# %%
X_test.shape
# Out:
# (415, 224, 224, 3)

# %%
from keras.applications.vgg16 import VGG16

# %%
vgg = VGG16()

# %%
vgg.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
from keras import Sequential

# %%
model = Sequential()

# %%
for layer in vgg.layers[:-1]:
    model.add(layer)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ...

# %%
for layer in model.layers:
    layer.trainable=False

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ...

# %%
from keras.layers import Dense

# %%
model.add(Dense(1,activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ...

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 249s 5s/step - accuracy: 0.6057 - loss: 0.6440 - val_accuracy: 0.8482 - val_loss: 0.4100
# Epoch 2/5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 264s 5s/step - accuracy: 0.8427 - loss: 0.4002 - val_accuracy: 0.8530 - val_loss: 0.3424
# Epoch 3/5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 292s 6s/step - accuracy: 0.8915 - loss: 0.3191 - val_accuracy: 0.8867 - val_loss: 0.2994
# Epoch 4/5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 287s 6s/step - accuracy: 0.9068 - loss: 0.2647 - val_accuracy: 0.8867 - val_loss: 0.2843
# Epoch 5/5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 282s 5s/step - accuracy: 0.9126 - loss: 0.2512 - val_accuracy: 0.9060 - val_loss: 0.2586

# %%
cap = cv2.VideoCapture(0)

# %%
while True:
    
    ret, frame = cap.read()

    img = cv2.resize(frame,(250,250))

    y_pred = detect_face_mask(img)

    if y_pred == 0:
        draw_label(frame,"Face Mask",(20,20),(0,255,0))
    else:
        draw_label(frame,"NO Face Mask",(20,20),(0,0,255))
        cv2.imshow("window",frame)

    if cv2.waitKey(1) & 0xFF == ord('x'):
        break


cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# ...

# %%
def detect_face_mask(img):

    y_pred = model.predict(img.reshape(1,250,250,3))
    
    return y_pred[0][0]

# %%
sample1 = cv2.imread('sample/1mask.jpg')
sample1 = cv2.resize(sample1,(250,250))

# %%
detect_face_mask(sample1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 4.1599642e-07

# %%
def draw_label(img,text,pos,bg_color):
    text_size = cv2.getTextSize(text,cv2.FONT_HERSHEY_SIMPLEX,1,cv2.FILLED)
    end_x = pos[0] + text_size[0][0] + 2
    end_y = pos[1] + text_size[0][1] - 2

    cv2.rectangle(img,pos,(end_x,end_y),bg_color,cv2.FILLED)
    cv2.putText(img,text,pos,cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),1,cv2.LINE_AA)
